# %%
print("Hello")
# Out:
# Hello

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plane(x, y, z):
    return (z - 2 * x - 3 * y)

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)

# Values of z to visualize
z_values = [x for x in range(-10, 10)]  # Change these as needed

# Set up the plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

# Plot the planes for each z value
for z in z_values:
    z_plane = plane(x, y, z)
    ax.plot_surface(x, y, z_plane, alpha=0.5, label=f'z = {z}')

# Add labels and a legend
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.title("Planes for 2x + 3y = z")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 18
#      16 for z in z_values:
#      17     z_plane = plane(x, y, z)
# ---> 18     ax.plot_surface(x, y, z_plane, alpha=0.5, label=f'z = {z}')
#      20 # Add labels and a legend
#      21 ax.set_xlabel('X-axis')
#
# AttributeError: 'Axes' object has no attribute 'plot_surface'
